# %%
# Import necessary functions
import sys
sys.path.append('../scripts')

from eda import plot_interaction_distribution, plot_activity_over_time, plot_activity_vs_weather, heatmap_correlation

# %%
# Load merged data
import pandas as pd
merged_df = pd.read_csv("../outputs/merged_data.csv")

# %%
# Plot interaction distribution
plot_interaction_distribution(merged_df)

# %%
# Plot activity over time
plot_activity_over_time(merged_df)

# %%
# Plot activity vs. temperature
plot_activity_vs_weather(merged_df, 'temp')

# %%
# Correlation heatmap
heatmap_correlation(merged_df)
